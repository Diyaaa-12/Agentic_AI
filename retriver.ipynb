# %% [markdown]
# # Enterprise AI Knowledge & Data Assistant
#
# ## Problem Statement
#
# TechNova Technologies is a software company whose information is distributed
# across different sources.
#
# The company has:
#
# - Internal company documents containing policies and organizational information
# - External information available through Wikipedia and Web Search
# - Employee and sales information stored in a SQL database
#
# Employees currently need to search these sources separately.
#
# The company wants to build an AI-powered Enterprise Assistant using
# LangChain and OpenRouter.
#
# ## Objective
#
# The AI agent should be able to:
#
# 1. Retrieve information from internal company documents.
# 2. Search external knowledge when required.
# 3. Query structured information from a SQL database.
# 4. Automatically select the appropriate tool.
# 5. Combine information from multiple tools when required.
# 6. Generate a natural-language answer.
#
# ---
# ## System Architecture
#
# <p align="center">
#
# <b>User</b>
# <br>
# ↓
# <br>
# <b>LangChain AI Agent</b>
# <br>
# ↓
# <br>
# <b>OpenRouter LLM</b>
# <br>
# ↓
# <br>
# <b>Intelligent Tool Selection</b>
#
# </p>
#
# <table align="center">
# <tr>
# <td align="center" width="33%">
#
# <b>Retrieval Tool</b>
# <br><br>
# ↓
# <br><br>
# <b>Chroma Vector DB</b>
# <br><br>
# ↓
# <br><br>
# <b>Company Documents</b>
#
# </td>
#
# <td align="center" width="33%">
#
# <b>External Search Tool</b>
# <br><br>
# ↓
# <br><br>
# <b>Wikipedia / Web Search</b>
# <br><br>
# ↓
# <br><br>
# <b>External Knowledge</b>
#
# </td>
#
# <td align="center" width="33%">
#
# <b>Database Tool</b>
# <br><br>
# ↓
# <br><br>
# <b>SQLite Database</b>
# <br><br>
# ↓
# <br><br>
# <b>Company Data</b>
#
# </td>
# </tr>
# </table>
#
# <p align="center">
#
# ↓
# <br>
# <b>Tool Results</b>
# <br>
# ↓
# <br>
# <b>OpenRouter LLM</b>
# <br>
# ↓
# <br>
# <b>Final Natural-Language Answer</b>
#
# </p>
#
# ---
#
# ## Key Concept
#
# <p align="center">
#
# <b>Agentic AI = LLM + Tools + Decision Making + External Data</b>
#
# </p>

# %%
# Install required libraries

! pip install -U langchain langchain-openrouter langchain-community langchain-chroma chromadb sentence-transformers wikipedia
# Out:
# Requirement already satisfied: langchain in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (1.3.16)
# Collecting langchain
#   Downloading langchain-1.4.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: langchain-openrouter in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (0.2.8)
# Requirement already satisfied: langchain-community in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-chroma in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (1.5.9)
# Collecting sentence-transformers
#   Downloading sentence_transformers-6.0.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: wikipedia in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: openrouter<1.0.0,>=0.9.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-openrouter) (0.11.46)
# Requirement already satisfied: jsonpath-python>=1.0.6 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from openrouter<1.0.0,>=0.9.2->langchain-openrouter) (1.1.6)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-community) (2.5.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: build>=1.0.3 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.4)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (4.70.0)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (0.27.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from chromadb) (4.26.0)
# Collecting transformers<6.0.0,>=5.0.0 (from sentence-transformers)
#   Downloading transformers-5.16.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.3.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from sentence-transformers) (1.28.0)
# Collecting torch>=2.2 (from sentence-transformers)
#   Downloading torch-2.14.0-cp313-cp313-win_amd64.whl.metadata (38 kB)
# Collecting scikit-learn>=1.1.0 (from sentence-transformers)
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from sentence-transformers) (1.18.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (3.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: colorama in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex>=2025.10.22 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (2026.7.19)
# Collecting safetensors>=0.8.0 (from transformers<6.0.0,>=5.0.0->sentence-transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: beautifulsoup4 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from wikipedia) (4.15.0)
# Requirement already satisfied: pyproject_hooks in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.35.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from rich>=10.11.0->chromadb) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Collecting joblib>=1.4.0 (from scikit-learn>=1.1.0->sentence-transformers)
#   Downloading joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn>=1.1.0->sentence-transformers)
#   Downloading narwhals-2.25.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn>=1.1.0->sentence-transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn>=1.1.0->sentence-transformers)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: setuptools>=77.0.3 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from torch>=2.2->sentence-transformers) (84.0.0)
# Collecting sympy>=1.13.3 (from torch>=2.2->sentence-transformers)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.2->sentence-transformers)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from torch>=2.2->sentence-transformers) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.2->sentence-transformers)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from beautifulsoup4->wikipedia) (2.9.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from jinja2->torch>=2.2->sentence-transformers) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Downloading langchain-1.4.0-py3-none-any.whl (161 kB)
# Downloading sentence_transformers-6.0.1-py3-none-any.whl (739 kB)
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/739.8 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/739.8 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/739.8 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/739.8 kB ? eta -:--:--
#    -------------------------- ----------- 524.3/739.8 kB 320.7 kB/s eta 0:00:01
#    -------------------------- ----------- 524.3/739.8 kB 320.7 kB/s eta 0:00:01
#    ---------------------------------------- 739.8/739.8 kB 320.0 kB/s  0:00:04
# Downloading transformers-5.16.1-py3-none-any.whl (12.1 MB)
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.1 MB 273.6 kB/s eta 0:00:43
#    - -------------------------------------- 0.5/12.1 MB 273.6 kB/s eta 0:00:43
#    - -------------------------------------- 0.5/12.1 MB 273.6 kB/s eta 0:00:43
#    - -------------------------------------- 0.5/12.1 MB 273.6 kB/s eta 0:00:43
#    - -------------------------------------- 0.5/12.1 MB 273.6 kB/s eta 0:00:43
#    -- ------------------------------------- 0.8/12.1 MB 266.2 kB/s eta 0:00:43
#    -- ------------------------------------- 0.8/12.1 MB 266.2 kB/s eta 0:00:43
#    ------- ------------------------------- 23.6/124.1 MB 910.0 kB/s eta 0:01:51
#    ------- ------------------------------- 24.4/124.1 MB 932.8 kB/s eta 0:01:47
#    ------- ------------------------------- 24.9/124.1 MB 948.2 kB/s eta 0:01:45
#    ------- ------------------------------- 25.2/124.1 MB 946.1 kB/s eta 0:01:45
#    ------- ------------------------------- 25.2/124.1 MB 946.1 kB/s eta 0:01:45
#    ------- ------------------------------- 25.2/124.1 MB 946.1 kB/s eta 0:01:45
#    ------- ------------------------------- 25.2/124.1 MB 946.1 kB/s eta 0:01:45
#    ------- ------------------------------- 25.4/124.1 MB 926.2 kB/s eta 0:01:47
#    -------- ------------------------------ 26.2/124.1 MB 948.0 kB/s eta 0:01:44
#    -------- ------------------------------ 26.7/124.1 MB 961.0 kB/s eta 0:01:42
#    -------- ------------------------------ 27.5/124.1 MB 979.5 kB/s eta 0:01:39
#    -------- ------------------------------ 28.0/124.1 MB 990.5 kB/s eta 0:01:37
#    --------- ------------------------------ 29.1/124.1 MB 1.0 MB/s eta 0:01:34
#    --------- ------------------------------ 29.4/124.1 MB 1.0 MB/s eta 0:01:33
#    --------- ------------------------------ 29.9/124.1 MB 1.0 MB/s eta 0:01:32
#    --------- ------------------------------ 30.1/124.1 MB 1.0 MB/s eta 0:01:31
#    --------- ------------------------------ 30.7/124.1 MB 1.0 MB/s eta 0:01:30
#    --------- ------------------------------ 30.9/124.1 MB 1.0 MB/s eta 0:01:29
#    ---------- ----------------------------- 31.7/124.1 MB 1.1 MB/s eta 0:01:27
#    ---------- ----------------------------- 32.2/124.1 MB 1.1 MB/s eta 0:01:26
#    ---------- ----------------------------- 32.5/124.1 MB 1.1 MB/s eta 0:01:26
# ...
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    --------------------- ------------------  7/13 [torch]
#    ------------------------ ---------------  8/13 [joblib]
#    ------------------------ ---------------  8/13 [joblib]
#    ------------------------ ---------------  8/13 [joblib]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    --------------------------- ------------  9/13 [scikit-learn]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    ------------------------------ --------- 10/13 [transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    --------------------------------- ------ 11/13 [sentence-transformers]
#   Attempting uninstall: langchain
#    --------------------------------- ------ 11/13 [sentence-transformers]
#     Found existing installation: langchain 1.3.16
#    --------------------------------- ------ 11/13 [sentence-transformers]
#     Uninstalling langchain-1.3.16:
#    --------------------------------- ------ 11/13 [sentence-transformers]
#       Successfully uninstalled langchain-1.3.16
#    --------------------------------- ------ 11/13 [sentence-transformers]
#    ------------------------------------ --- 12/13 [langchain]
#    ------------------------------------ --- 12/13 [langchain]
#    ---------------------------------------- 13/13 [langchain]
#
# Successfully installed cloudpickle-3.1.2 joblib-1.6.0 langchain-1.4.0 mpmath-1.3.0 narwhals-2.25.0 networkx-3.6.1 safetensors-0.8.0 scikit-learn-1.9.0 sentence-transformers-6.0.1 sympy-1.14.0 threadpoolctl-3.6.0 torch-2.14.0 transformers-5.16.1
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

if not OPENROUTER_API_KEY:
    raise ValueError("OPENROUTER_API_KEY not found in .env file")

print("OpenRouter API key loaded successfully.")
# Out:
# OpenRouter API key loaded successfully.

# %%
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="z-ai/glm-5.3-flash",
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
    temperature=0
)

print("Model initialized successfully")
# Out:
# Model initialized successfully

# %%
response = model.invoke("Explain what an AI agent is in one sentence.")

print(response.content)
# Out:
# An AI agent is an artificial intelligence system that can autonomously perceive its environment, make decisions, and take actions to achieve specific goals.

# %%
from langchain_core.documents import Document

# TechNova internal company documents

documents = [
    Document(
        page_content="""
        TechNova Technologies is a software company specializing in
        Artificial Intelligence, Cloud Computing, Cybersecurity,
        and Software Development.

        The company has offices in Hyderabad, Bangalore, and Delhi.
        """
    ),

    Document(
        page_content="""
        TechNova Employee Work From Home Policy:

        Employees can work remotely up to 2 days per week.
        Remote work requires approval from the employee's manager.
        Employees must remain available during official working hours.
        """
    ),

    Document(
        page_content="""
        TechNova Employee Benefits:

        Employees receive 24 annual paid leaves.
        The company provides an annual learning budget of
        30000 INR for approved technical courses, conferences,
        and professional development programs.
        """
    ),

    Document(
        page_content="""
        TechNova Working Hours:

        Standard working hours are from 9:30 AM to 6:30 PM.
        Employees are expected to complete their assigned working hours.
        Flexible working arrangements require manager approval.
        """
    )
]

print(f"Number of documents: {len(documents)}")
# Out:
# Number of documents: 4

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_chroma import Chroma

# Create the embedding model
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# Create Chroma vector database
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embeddings,
    collection_name="technova_knowledge"
)

print("Chroma vector database created successfully!")
# Out:
# C:\Users\smart\AppData\Local\Temp\ipykernel_11208\1448419136.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.embeddings import HuggingFaceEmbeddings
# C:\Users\smart\AppData\Local\Temp\ipykernel_11208\1448419136.py:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\smart\Documents\KIET\Agentic Ai Industry practicals\venv\Lib\site-packages\huggingface_hub\file_download.py:141: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\smart\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Chroma vector database created successfully!

# %%
from langchain_chroma import Chroma

retriever = vectorstore.as_retriever(
    search_kwargs={"k": 2}
)

# %%
results = retriever.invoke(
    "What is TechNova's work from home policy?"
)

for doc in results:
    print(doc.page_content)
# Out:
#         TechNova Employee Work From Home Policy:
#
#         Employees can work remotely up to 2 days per week.
#         Remote work requires approval from the employee's manager.
#         Employees must remain available during official working hours.
#
#
#         TechNova Technologies is a software company specializing in
#         Artificial Intelligence, Cloud Computing, Cybersecurity,
#         and Software Development.
#
#         The company has offices in Hyderabad, Bangalore, and Delhi.

# %%
from langchain_core.tools import tool

@tool
def search_company_documents(query: str) -> str:
    """
    Search TechNova's internal company documents.

    Use this tool for company policies, working hours,
    employee benefits, offices, and other internal information.
    """
    
    docs = retriever.invoke(query)
    
    return "\n\n".join(
        doc.page_content for doc in docs
    )

print("Retrieval tool created successfully!")
# Out:
# Retrieval tool created successfully!

# %%
result = search_company_documents.invoke({
    "query": "What is TechNova's work from home policy?"
})

print(result)
# Out:
#         TechNova Employee Work From Home Policy:
#
#         Employees can work remotely up to 2 days per week.
#         Remote work requires approval from the employee's manager.
#         Employees must remain available during official working hours.
#
#
#
#         TechNova Technologies is a software company specializing in
#         Artificial Intelligence, Cloud Computing, Cybersecurity,
#         and Software Development.
#
#         The company has offices in Hyderabad, Bangalore, and Delhi.

# %%
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_community.tools import WikipediaQueryRun

# Create Wikipedia API wrapper
wiki_wrapper = WikipediaAPIWrapper(
    top_k_results=2,
    doc_content_chars_max=3000
)

# Create LangChain Wikipedia tool
wikipedia_tool = WikipediaQueryRun(
    api_wrapper=wiki_wrapper
)

print("Wikipedia tool created successfully!")
# Out:
# Wikipedia tool created successfully!

# %%
result = wikipedia_tool.invoke("Artificial Intelligence")

print(result)
# Out:
# Page: Artificial intelligence
# Summary: Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in engineering, mathematics, and computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximise their chances of achieving defined goals.
# High-profile applications of AI include advanced web search engines, chatbots, virtual assistants, autonomous vehicles, play and analysis in strategy games (e.g., chess and Go), and content generation (e.g. images, audio, and videos).
# The traditional goals of AI research include learning, reasoning, knowledge representation, planning, natural language processing, and perception, as well as support for robotics. To reach these goals, AI researchers use techniques including state space search and mathematical optimisation, formal logic, artificial neural networks, and methods based on statistics, operations research, and economics. AI also draws upon psychology, linguistics, philosophy, neuroscience, and other fields. Some companies, such as OpenAI, Google DeepMind, and Meta, aim to create artificial general intelligence (AGI)—AI that can complete nearly any cognitive task at least as well as a human.
# Artificial intelligence was founded as an academic discipline in 1956. The field went through multiple cycles of optimism throughout its history, followed by periods of disappointment and loss of funding, known as AI winters. Funding and interest increased substantially after 2012, when graphics processing units (GPUs) started being used to accelerate neural networks, and deep learning outperformed previous AI techniques. This growth accelerated further after 2017 with the transformer architecture. In the 2020s, an AI boom coincided with advances in generative AI, which became widespread and allowed for the creation and modification of media. In addition to AI safety and unintended consequences and harms from the use of AI, ethical concerns, AI's long-term effects, environmental effects, and potential existential risks have prompted discussions of AI regulation.
#
#
#
# Page: Artificial general intelligence
# Summary: Artificial general intelligence (AGI) is a hypothetical type of artificial intelligence that matches or surpasses human capabilities across virtually all cognitive tasks.
# Beyond AGI, artificial superintelligence (ASI) would outperform the best human abilities across every domain by a wide margin. Unlike artificial narrow intelligence (ANI), whose competence is confined to well‑defined tasks, an AGI system can generalise knowledge, transfer skills between domains, and solve novel problems without task‑specific reprogramming.
# Creating AGI is a stated goal of technology companies such as OpenAI, Google, SpaceXAI, and Meta. A

# %%
import sqlite3



conn = sqlite3.connect("technova.db")
cursor = conn.cursor()



cursor.execute("""
CREATE TABLE IF NOT EXISTS employees (
    id INTEGER PRIMARY KEY,
    name TEXT,
    department TEXT,
    salary INTEGER
)
""")



cursor.execute("""
CREATE TABLE IF NOT EXISTS sales (
    id INTEGER PRIMARY KEY,
    product TEXT,
    region TEXT,
    amount INTEGER
)
""")



employees = [
    (1, "Rahul Sharma", "AI", 85000),
    (2, "Priya Singh", "Data Science", 92000),
    (3, "Arjun Kumar", "Software", 78000),
    (4, "Sneha Patel", "HR", 65000),
    (5, "Vikram Reddy", "AI", 95000),
    (6, "Ananya Das", "Finance", 72000),
    (7, "Rohit Verma", "Software", 88000),
    (8, "Meera Nair", "Data Science", 90000),
    (9, "Karan Gupta", "Sales", 70000),
    (10, "Neha Joshi", "AI", 87000)
]

cursor.executemany("""
INSERT OR REPLACE INTO employees
(id, name, department, salary)
VALUES (?, ?, ?, ?)
""", employees)



sales = [
    (1, "Laptop", "North", 120000),
    (2, "Smartphone", "South", 95000),
    (3, "Tablet", "East", 75000),
    (4, "Laptop", "West", 140000),
    (5, "Smartwatch", "North", 55000),
    (6, "Smartphone", "East", 110000),
    (7, "Laptop", "South", 135000),
    (8, "Tablet", "West", 82000),
    (9, "Smartwatch", "East", 62000),
    (10, "Laptop", "North", 155000),
    (11, "Smartphone", "West", 105000),
    (12, "Tablet", "South", 78000),
    (13, "Smartwatch", "North", 59000),
    (14, "Laptop", "East", 130000),
    (15, "Smartphone", "North", 125000)
]

cursor.executemany("""
INSERT OR REPLACE INTO sales
(id, product, region, amount)
VALUES (?, ?, ?, ?)
""", sales)



conn.commit()

print("SQLite database created and sample data inserted successfully!")

conn.close()
# Out:
# SQLite database created and sample data inserted successfully!

# %%
import sqlite3

conn = sqlite3.connect("technova.db")

cursor = conn.cursor()

print("EMPLOYEES")
print("=" * 50)

cursor.execute("SELECT * FROM employees")

for row in cursor.fetchall():
    print(row)

print("\nSALES")
print("=" * 50)

cursor.execute("SELECT * FROM sales")

for row in cursor.fetchall():
    print(row)

conn.close()
# Out:
# EMPLOYEES
# ==================================================
# (1, 'Rahul Sharma', 'AI', 85000)
# (2, 'Priya Singh', 'Data Science', 92000)
# (3, 'Arjun Kumar', 'Software', 78000)
# (4, 'Sneha Patel', 'HR', 65000)
# (5, 'Vikram Reddy', 'AI', 95000)
# (6, 'Ananya Das', 'Finance', 72000)
# (7, 'Rohit Verma', 'Software', 88000)
# (8, 'Meera Nair', 'Data Science', 90000)
# (9, 'Karan Gupta', 'Sales', 70000)
# (10, 'Neha Joshi', 'AI', 87000)
#
# SALES
# ==================================================
# (1, 'Laptop', 'North', 120000)
# (2, 'Smartphone', 'South', 95000)
# (3, 'Tablet', 'East', 75000)
# (4, 'Laptop', 'West', 140000)
# (5, 'Smartwatch', 'North', 55000)
# (6, 'Smartphone', 'East', 110000)
# (7, 'Laptop', 'South', 135000)
# (8, 'Tablet', 'West', 82000)
# (9, 'Smartwatch', 'East', 62000)
# (10, 'Laptop', 'North', 155000)
# (11, 'Smartphone', 'West', 105000)
# (12, 'Tablet', 'South', 78000)
# (13, 'Smartwatch', 'North', 59000)
# (14, 'Laptop', 'East', 130000)
# (15, 'Smartphone', 'North', 125000)

# %%
! pip install -q langchain langchain-community sqlalchemy
# Out:
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.utilities import SQLDatabase

# Connect LangChain to SQLite database
db = SQLDatabase.from_uri("sqlite:///technova.db")

print("Database connected successfully!")
# Out:
# Database connected successfully!

# %%
print(db.get_usable_table_names())
# Out:
# ['employees', 'sales']

# %%
print(db.get_table_info())
# Out:
# CREATE TABLE employees (
# 	id INTEGER,
# 	name TEXT,
# 	department TEXT,
# 	salary INTEGER,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from employees table:
# id	name	department	salary
# 1	Rahul Sharma	AI	85000
# 2	Priya Singh	Data Science	92000
# 3	Arjun Kumar	Software	78000
# */
#
#
# CREATE TABLE sales (
# 	id INTEGER,
# 	product TEXT,
# 	region TEXT,
# 	amount INTEGER,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from sales table:
# id	product	region	amount
# 1	Laptop	North	120000
# 2	Smartphone	South	95000
# 3	Tablet	East	75000
# */

# %%
from langchain_community.agent_toolkits import create_sql_agent

agent = create_sql_agent(
    llm=model,
    db=db,
    agent_type="tool-calling",
    verbose=True
)

print("SQL Agent created successfully!")
# Out:
# SQL Agent created successfully!

# %%
question = "Who is the highest paid employee?"

response = agent.invoke({
    "input": question
})

print(response["output"])
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{'tool_input': ''}`
#
#
# employees, sales
# Invoking: `sql_db_schema` with `{'table_names': 'employees'}`
#
#
#
# CREATE TABLE employees (
# 	id INTEGER,
# 	name TEXT,
# 	department TEXT,
# 	salary INTEGER,
# 	PRIMARY KEY (id)
# )
#
# /*
# 3 rows from employees table:
# id	name	department	salary
# 1	Rahul Sharma	AI	85000
# 2	Priya Singh	Data Science	92000
# 3	Arjun Kumar	Software	78000
# */
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT name, department, salary FROM employees ORDER BY salary DESC LIMIT 1'}`
# responded: I can see the `employees` table has a `salary` column. Let me check my query before executing it.
#
# SELECT name, department, salary FROM employees ORDER BY salary DESC LIMIT 1
# Invoking: `sql_db_query` with `{'query': 'SELECT name, department, salary FROM employees ORDER BY salary DESC LIMIT 1'}`
# responded: The query is valid. Now let me execute it:
#
# [('Vikram Reddy', 'AI', 95000)]The highest paid employee is **Vikram Reddy**, who works in the **AI** department with a salary of **95,000**.
#
# > Finished chain.
# The highest paid employee is **Vikram Reddy**, who works in the **AI** department with a salary of **95,000**.
